# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %load font.py
#!/usr/bin/env python

# In[1]:


import platform
if platform.system() == 'Darwin': #맥
        plt.rc('font', family='AppleGothic') 
elif platform.system() == 'Windows': #윈도우
        plt.rc('font', family='Malgun Gothic') 
elif platform.system() == 'Linux': #리눅스 (구글 콜랩)
        plt.rc('font', family='Malgun Gothic') 

plt.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 마이너스 폰트 깨짐 해결

# %%
#선 그래프
#시도별 진출입 인구수

df=pd.read_excel('C:/Users/JYP/Documents/pandas/dataset/시도별 전출입 인구수.xlsx', engine='openpyxl', header=0)

# %%
#전출지의 Nan 자료를 수정 -> 이전 자료 값으로 대체
df=df.fillna(method='ffill') # nan 자료를 이전 자료로 대체

# %%
# 서울특별시에서 다른 곳으로 전출한 자료만 출력
mask=(df['전출지별']=='서울특별시') & (df['전입지별']!='서울특별시')
df_seoul=df[mask]
print(df_seoul)

# 필요없는 컬럼 삭제/전출지별과 같음
df_seoul=df_seoul.drop(['전출지별'],axis=1)
print(df_seoul.tail(3))

#전입지별을 전입지로 변경
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul

#인덱스를 전입지로 변경
df_seoul.set_index('전입지',inplace=True) 
df_seoul.tail(8)
# Out:
#      전출지별     전입지별     1970     1971     1972     1973     1974     1975  \
# 19  서울특별시       전국  1448985  1419016  1210559  1647268  1819660  2937093
# 21  서울특별시    부산광역시    11568    11130    11768    16307    22220    27515
# 22  서울특별시    대구광역시        -        -        -        -        -        -
# 23  서울특별시    인천광역시        -        -        -        -        -        -
# 24  서울특별시    광주광역시        -        -        -        -        -        -
# 25  서울특별시    대전광역시        -        -        -        -        -        -
# 26  서울특별시    울산광역시        -        -        -        -        -        -
# 27  서울특별시  세종특별자치시        -        -        -        -        -        -
# 28  서울특별시      경기도   130149   150313    93333   143234   149045   253705
# 29  서울특별시      강원도     9352    12885    13561    16481    15479    27837
# 30  서울특별시     충청북도     6700     9457    10853    12617    11786    21073
# 31  서울특별시     충청남도    15954    18943    23406    27139    25509    51205
# ...

# %%
#서울에서 경기도로 전입한 인구수 그래프로 확인
sr_one=df_seoul.loc['경기도']
sr_one.head(3)
sr_one.index
sr_one.values
# Out:
# array([130149, 150313, 93333, 143234, 149045, 253705, 202276, 207722,
#        237684, 278411, 297539, 252073, 320174, 400875, 352238, 390265,
#        412535, 405220, 415174, 412933, 473889, 384714, 428344, 502584,
#        542204, 599411, 520566, 495454, 407050, 471841, 435573, 499575,
#        516765, 457656, 400206, 414621, 449632, 431637, 412408, 398282,
#        410735, 373771, 354135, 340801, 332785, 359337, 370760, 342433],
#       dtype=object)

# %%
plt.plot(sr_one.index, sr_one.values)
plt.title('서울->경기 인구 이동')
plt.xlabel('기간')
plt.ylabel('이동 인구수')

# plt.show()

plt.figure(figsize=(14,5))
plt.show()

# %%
col_years=list(map(str,range(1970,2018)))
df_4=df_seoul.loc[['충청남도','경상북도','강원도','전라남도'],col_years]

plt.style.use('ggplot')

fig=plt.figure(figsize=(20,10))
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

ax1.plot(col_years,df_4.loc['충청남도',:], marker='o',markerfacecolor='green',markersize=10,color='olive',linewidth=2,label='서울->충남')
ax2.plot(col_years,df_4.loc['경상북도',:], marker='o',markerfacecolor='blue',markersize=10,color='skyblue',linewidth=2,label='서울->경북')
ax3.plot(col_years,df_4.loc['강원도',:], marker='o',markerfacecolor='red',markersize=10,color='magenta',linewidth=2,label='서울->강원')
ax4.plot(col_years,df_4.loc['전라남도',:], marker='o',markerfacecolor='orange',markersize=10,color='yellow',linewidth=2,label='서울->전남')

ax1.legend(loc='best')
ax2.legend(loc='best')
ax3.legend(loc='best')
ax4.legend(loc='best')

ax1.set_title('서울->충남 인구 이동', size=15)
ax2.set_title('서울->경북 인구 이동', size=15)
ax3.set_title('서울->강원 인구 이동', size=15)
ax4.set_title('서울->전남 인구 이동', size=15)

ax1.set_xticklabels(col_years,rotation=90)
ax2.set_xticklabels(col_years,rotation=90)
ax3.set_xticklabels(col_years,rotation=90)
ax4.set_xticklabels(col_years,rotation=90)

plt.show()
# Out:
# C:\Users\JYP\AppData\Local\Temp/ipykernel_7412/460216673.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(col_years,rotation=90)
# C:\Users\JYP\AppData\Local\Temp/ipykernel_7412/460216673.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(col_years,rotation=90)
# C:\Users\JYP\AppData\Local\Temp/ipykernel_7412/460216673.py:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(col_years,rotation=90)
# C:\Users\JYP\AppData\Local\Temp/ipykernel_7412/460216673.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(col_years,rotation=90)

# %%
# df_4=df_4.T
# print(df_4)

ax=df_4.plot(kind='area',figsize=(16,10),alpha=0.3,stacked=True) #alpha는 투과율

ax.legend(loc='best')

# %%
ax=df_4.plot(kind='bar',figsize=(16,10),width=0.7) #alpha는 투과율

ax.legend(loc='best')
