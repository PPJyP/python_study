# %%
import requests
from bs4 import BeautifulSoup

target=requests.get("https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20211229")
soup=BeautifulSoup(target.text) # 텍스트로 가져오기 가능
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image"/>
# <meta content="네이버영화 " property="me2:post_tag"/>
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20211229" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
count=0
for rec in soup.find_all('tr'): 
    if rec.find('td', class_='ac'):
        count+=1
        print("{}위, {}, {}점".\
              format(count, rec.find('div', class_='tit5').text, rec.find('td', class_='point').text))
# Out:
# 1위,
# 매트릭스
# , 9.40점
# 2위,
# 코다
# , 9.24점
# 3위,
# 꽃다발 같은 사랑을 했다
# , 9.03점
# 4위,
# 스파이더맨: 노 웨이 홈
# , 9.03점
# 5위,
# 러브 액츄얼리
# , 8.93점
# 6위,
# 기쿠지로의 여름
# , 8.92점
# 7위,
# 아멜리에
# , 8.81점
# 8위,
# 고양이를 부탁해
# , 8.81점
# 9위,
# 너의 이름은.
# , 8.80점
# 10위,
# 공각기동대
# , 8.72점
# 11위,
# 돈 룩 업
# , 8.65점
# 12위,
# 너와 파도를 탈 수 있다면
# , 8.53점
# 13위,
# 태일이
# , 8.49점
# 14위,
# 초속5센티미터
# , 8.35점
# 15위,
# 엔칸토: 마법의 세계
# , 8.32점
# 16위,
# 연애 빠진 로맨스
# , 8.31점
# 17위,
# 킹스맨: 퍼스트 에이전트
# , 8.22점
# 18위,
# 프렌치 디스패치
# , 8.03점
# 19위,
# 날씨의 아이
# , 7.96점
# 20위,
# 라스트 나잇 인 소호
# , 7.84점
# 21위,
# 유체이탈자
# , 7.59점
# 22위,
# 디어 에반 핸슨
# , 7.50점
# 23위,
# 아네트
# , 7.28점
# 24위,
# 장르만 로맨스
# , 6.66점
# 25위,
# 베놈 2: 렛 데어 비 카니지
# , 6.11점
# 26위,
# 매트릭스: 리저렉션
# , 5.65점
# 27위,
# 이터널스
# , 5.57점
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3840/3017006883.py in <module>
#       4         count+=1
# ...

# %%
#학생, 국어,영어,수학 점수를 입력 받아 student_dict{}에 저장한 후 출력

# student={'name':, 'kr':, 'eng':, 'math':}
def create_student():
    student={}
    name=input("학생 이름 입력 :")
    student['name']=name
    if name =='q':
        return student
    score=list(map(int, input("국어, 영어, 수학, 점수 입력 :").split()))
    for idx, value in enumerate(score):
        student[score_name[idx]]=score[idx]
    return student

# %%
students=[] # [{}'name':'홍길동','kor':90,'eng':80,'math':90},]
score_name=['kor','eng','math']
while True:
    student= create_student()
    if student['name']=='q':
        break
    students.append(student)
# Out:
# 학생 이름 입력 :ab
# 국어, 영어, 수학, 점수 입력 :10 20 30
# 학생 이름 입력 :cd
# 국어, 영어, 수학, 점수 입력 :20 30 40
# 학생 이름 입력 :q

# %%
def student_get_sum(student):
    return student['kor']+student['eng']+student['math']

def student_get_avg(student):
    return student_get_sum(student)/3

def student_print(students):
    for value in students:
        for key in value:
            print("{} : {}\t".format(key,value[key]), end='')
        print("총점:{}\t,avg:{}".format(student_get_sum(value),
                                     student_get_avg(value)))
        print("\n")

# %%
student_print(students)
# Out:
# name : ab	kor : 10	eng : 20	math : 30	총점:60	,avg:20.0
#
#
# name : cd	kor : 20	eng : 30	math : 40	총점:90	,avg:30.0

# %%
# class 생성하기 calss 클래스명 : ~~~

class Student:
    def __init__(self,name,kor,eng,math):
        self.name=name
        self.kor=kor
        self.eng=eng
        self.math=math
        
    def get_sum(self):
        return self.kor+self.eng+self.math
    def get_avg(self):
        return self.get_sum/3
    def to_print(self):
        return "{}:{}\t {}\n".format(self.name, self.get_sum(),self.get_avg())

# %%
def create_student():
    name=input("학생 이름 입력 :")
    if name =='q':
        return name
    score=list(map(int, input("국어, 영어, 수학, 점수 입력 :").split()))
    kor=score[0]
    eng=score[1]
    math=score[2]
    student=Student(name,kor,eng,math)
    return student

# %% [markdown]
# students=[]
# while True:
#     name=input("학생 이름 입력 :")
#     if name =='q':
#         break
#     score=list(map(int, input("국어, 영어, 수학, 점수 입력 :").split()))
#     kor=score[0]
#     eng=score[1]
#     math=score[2]
#     student=Student(name,kor,eng,math)
#     students.append(student)

# %%
for student in students:
    print(student.to_print())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3552/2994545383.py in <module>
# ----> 1 for student in students:
#       2     print(student.to_print())
#
# NameError: name 'students' is not defined

# %%
class Store:
    def __init__(self, 이름, 전화번호, 주소):
        self.이름 = 이름
        self.전화번호 = 전화번호
    def order(self)

# %%
class Student:
    def study(self):
        print("공부를 합니다")
        
class Teacher:
    def teacher(self):
        print("가르칩니다")

# %%
classroom=[Student(),Teacher(),Student(),Student(),Teacher()]

for person in classroom:
    if isinstance(person, Student):
        person.study()
    else:
        person.teacher()
# Out:
# 공부를 합니다
# 가르칩니다
# 공부를 합니다
# 공부를 합니다
# 가르칩니다

# %%
# class는 틀이기 때문에 메모리에 올라가지 않음(while문과 같은건 들어가지 않음) - 함수 안에 생성해라
class Student:
    def __init__(self, name, kor,eng,math):
        self.name=name
        self.kor=kor
        self.eng=eng
        self.math=math

    def get_sum(self):
        return self.kor+self.eng+self.math
    def get_avg(self):
        return self.get_sum()/3
    def __str__(self):
        return "{}\t{}\t{}".format(self.name,self.get_sum(),self.get_avg())
    
    def __eq__(self, value):
        return self.get_sum()==value.get_sum()
    def __ne__(self, value):
        return self.get_sum()!=value.get_sum()
    def __gt__(self, value):
        return self.get_sum()>value.get_sum()

# %%
students = [
    Student("윤인성", 87, 98, 88),
    Student("연하진", 92, 98, 96),
    Student("구지연", 76, 96, 94),
    Student("나선주", 98, 92, 96),
    Student("윤아린", 95, 98, 98),
    Student("윤명월", 64, 88, 92)
]
student_a=Student("윤인성",87,98,88)
student_b=Student("연하진",92,98,86)

print("student_a== student_b=>",student_a==student_b)
print("student_a!= student_b=>",student_a!=student_b)

for student in students:
    if student==student_a or student==student_b:
        print(student.name,student.get_sum())
        
print(str(student)) # __str__은 그냥 불러서 사용가능
# Out:
# student_a== student_b=> False
# student_a!= student_b=> True
# 윤인성 273
# 윤명월	244	81.33333333333333

# %%
class Student:
    count=0 #클래스에 소속된 변수를 호출할 땐 Student.[변수명]
    student=[]
    def __init__(self, name, kor,eng,math):
        self.name=name
        self.kor=kor
        self.eng=eng
        self.math=math
        
        Student.count+=1
        Student.students.append(self)
        print("{}번째 입력 자료 :".format(Student.count))
    
    @classmethod
    def print(cls):
        print("--학생 목록--")
        print("이름\t총점\t평균")
        for student in cls.students:
            print(str(student))
        print("-----------------")
        
    def get_sum(self):
        return self.kor+self.eng+self.math
    def get_avg(self):
        return self.get_sum()/3
    def __str__(self):
        return "{}\t{}\t{}".format(self.name,self.get_sum(),self.get_avg())

# %%
students = [
    Student("윤인성", 87, 98, 88),
    Student("연하진", 92, 98, 96),
    Student("구지연", 76, 96, 94),
    Student("나선주", 98, 92, 96),
    Student("윤아린", 95, 98, 98),
    Student("윤명월", 64, 88, 92)
]
Student.print()
print("전체 인원수 :",Student.count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3552/2573737905.py in <module>
#       1 students = [
# ----> 2     Student("윤인성", 87, 98, 88),
#       3     Student("연하진", 92, 98, 96),
#       4     Student("구지연", 76, 96, 94),
#       5     Student("나선주", 98, 92, 96),
#
# ~\AppData\Local\Temp/ipykernel_3552/3108352186.py in __init__(self, name, kor, eng, math)
#       9
#      10         Student.count+=1
# ---> 11         Student.students.append(self)
#      12         print("{}번째 입력 자료 :".format(Student.count))
#      13
#
# AttributeError: type object 'Student' has no attribute 'students'

# %%
# 학생 자료를 입력 받아 클래스 리스트에 저장한 후
# 학생들의 각 과목별 점수와 총점 평균을 출력하고
#전체 학생의 인원수와 전체 학생의 총점과 평균을 구하세요

class Student:
    count=0 #클래스에 소속된 변수를 호출할 땐 Student.[변수명]
    student=[]
    def __init__(self, name, kor,eng,math):
        self.name=name
        self.kor=kor
        self.eng=eng
        self.math=math
        
        Student.count+=1
        Student.students.append(self)
        print("{}번째 입력 자료 :".format(Student.count))
    
    @classmethod
    def print(cls):
        print("--학생 목록--")
        print("이름\t총점\t평균")
        for student in cls.students:
            print(str(student))
        print("-----------------")
        
    def get_sum(self):
        return self.kor+self.eng+self.math
    def get_avg(self):
        return self.get_sum()/3
    def __str__(self):
        return "{}\t{}\t{}".format(self.name,self.get_sum(),self.get_avg())

# %%
while True:
    name=input("학생 이름 입력 :")
    if name =='q':
        break
    score=list(map(int, input("국어, 영어, 수학, 점수 입력 :").split()))
    kor=score[0]
    eng=score[1]
    math=score[2]
    Student(name,kor,eng,math)
    
Student.print()
total=0
for student in Student.students:
    total+=student.kor+student.eng+student.math
print("전체 인원수 : {}, 총점: {}, 평균: {:.3f}".format(Student.count.total.total/Student.count))
# Out:
# 학생 이름 입력 :r
# 국어, 영어, 수학, 점수 입력 :10 20 30
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3552/3504860973.py in <module>
#       7     eng=score[1]
#       8     math=score[2]
# ----> 9     Student(name,kor,eng,math)
#      10
#      11 Student.print()
#
# ~\AppData\Local\Temp/ipykernel_3552/1662945642.py in __init__(self, name, kor, eng, math)
#      13
#      14         Student.count+=1
# ---> 15         Student.students.append(self)
#      16         print("{}번째 입력 자료 :".format(Student.count))
#      17
#
# AttributeError: type object 'Student' has no attribute 'students'
